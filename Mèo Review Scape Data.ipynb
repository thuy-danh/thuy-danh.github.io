# %%
pip install webdriver_manager
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service as ChromeService

import time

from bs4 import BeautifulSoup

# %%
from webdriver_manager.chrome import ChromeDriverManager

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--headless")  # Optional: Run in headless mode

# Get the path to the downloaded ChromeDriver executable
chromedriver_path = ChromeDriverManager().install()

# Set the path to the ChromeDriver executable
chrome_options.binary_location = "/Applications/Google Chrome.app"  # Update this with the correct path

# Initialize Chrome browser
driver = webdriver.Chrome(options=chrome_options)

# %%
driver.get('https://www.youtube.com/@TheReviewer1208/videos')

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
html = driver.page_source

# %%
soup = BeautifulSoup(html,'html.parser')

# %%
videos = soup.find_all('div',{"id":"dismissible"})

# %%
videos
# Out:
# [<div class="style-scope ytd-rich-grid-media" id="dismissible"><div class="style-scope ytd-rich-grid-media" id="thumbnail"><ytd-thumbnail class="style-scope ytd-rich-grid-media" loaded="" rich-grid-thumbnail="" size="large" use-hovered-property="" width="9999"><!--css-build:shady--><a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=oNyfQqdV2Sg" id="thumbnail" rel="null" tabindex="-1">
#  <yt-image alt="" class="style-scope ytd-thumbnail" ftl-eligible="" notify-on-loaded="" notify-on-unloaded=""><img alt="" class="yt-core-image--fill-parent-height yt-core-image--fill-parent-width yt-core-image yt-core-image--content-mode-scale-aspect-fill yt-core-image--loaded" src="https://i.ytimg.com/vi/oNyfQqdV2Sg/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&amp;rs=AOn4CLCYCjRzrIACaVWaFl9ymDy1lEkXsg" style="background-color: transparent;"/></yt-image>
# ...

# %%
for video in videos:
    title = video.find('a',{'id':'video-title-link'})
    print(title.text)
    #break
# Out:
# Nếu một ngày tôi có khả năng điều khiển thời tiết|Recap Xàm: Siêu bão địa cầu
# Review Xàm: Breaking Bad
# Sự thật đen tối phía sau trang web phim tài liệu người lớn | Recap Xàm: Money Shot: The PH Story
# Thầy giáo tôi là bạch tuộc và cái kết khóc phết | Recap Xàm: Lớp Học Yêu Thương ss2 (pt.2)
# Oppenheimer hơi lòng vòng - Barbie bị cấm chiếu là đáng?
# Làm phụ nữ khổ hơn bạn nghĩ | Những vụ án nhắm vào phụ nữ
# Chiến dịch vườn không nhà trống nhưng là anime và siêu bẩn | Recap Xàm: Drifters phần 2
# Tại sao Hàn Quốc làm phim chuyển thể hay hơn Nhật?
# Điều sẽ xảy ra khi cha mẹ kiểm soát giới tính của con | Recap Xàm: Lớp Học Yêu Thương ss2 (pt.1
# Vì sao người nổi tiếng thích phát ngôn ngu? | Recap Xàm: Cái bẫy của sự nổi tiếng
# Review Xàm: Anh Hùng Trái Đất
# Khi Hitl.er chuyển sinh sang dị giới | Recap Xàm: Drifters (pt. 1)
# Michael Scofield chuyển sinh qua Nhật vượt ng.ục cực hay| Recap Xàm: Miền Đất Hứa
# ...

# %%
for video in videos:
    title = video.find('a', {'aria-label': True})
    print(title.text)
    #break
# Out:
# Nếu một ngày tôi có khả năng điều khiển thời tiết|Recap Xàm: Siêu bão địa cầu
# Review Xàm: Breaking Bad
# Sự thật đen tối phía sau trang web phim tài liệu người lớn | Recap Xàm: Money Shot: The PH Story
# Thầy giáo tôi là bạch tuộc và cái kết khóc phết | Recap Xàm: Lớp Học Yêu Thương ss2 (pt.2)
# Oppenheimer hơi lòng vòng - Barbie bị cấm chiếu là đáng?
# Làm phụ nữ khổ hơn bạn nghĩ | Những vụ án nhắm vào phụ nữ
# Chiến dịch vườn không nhà trống nhưng là anime và siêu bẩn | Recap Xàm: Drifters phần 2
# Tại sao Hàn Quốc làm phim chuyển thể hay hơn Nhật?
# Điều sẽ xảy ra khi cha mẹ kiểm soát giới tính của con | Recap Xàm: Lớp Học Yêu Thương ss2 (pt.1
# Vì sao người nổi tiếng thích phát ngôn ngu? | Recap Xàm: Cái bẫy của sự nổi tiếng
# Review Xàm: Anh Hùng Trái Đất
# Khi Hitl.er chuyển sinh sang dị giới | Recap Xàm: Drifters (pt. 1)
# Michael Scofield chuyển sinh qua Nhật vượt ng.ục cực hay| Recap Xàm: Miền Đất Hứa
# ...

# %%
title = video.find('a', {'aria-label': True})

# %%
title
# Out:
# <a aria-label="Liệu chỉ có một Jason Voorhees? | Giả Thuyết Xàm: Jason Voorhees của The Reviewer 1 tháng trước 8 phút, 59 giây 72.211 lượt xem" class="yt-simple-endpoint focus-on-expand style-scope ytd-rich-grid-media" href="/watch?v=GKB2sKQLal0" id="video-title-link" title="Liệu chỉ có một Jason Voorhees? | Giả Thuyết Xàm: Jason Voorhees"><yt-formatted-string aria-label="Liệu chỉ có một Jason Voorhees? | Giả Thuyết Xàm: Jason Voorhees của The Reviewer 1 tháng trước 8 phút, 59 giây 72.211 lượt xem" class="style-scope ytd-rich-grid-media" id="video-title">Liệu chỉ có một Jason Voorhees? | Giả Thuyết Xàm: Jason Voorhees</yt-formatted-string></a>

# %%
# Iterate through videos and get titles
for video in videos:
    title = video.find('a', {'aria-label': True})
    title = video.find('a', {'aria-label': True})
    if title:
        title_text = title['aria-label']
        view = title_text.split('trước')[-1]
        a = title_text.split('Review')

        #print(title.text)
        print(view)
        #print(video_age)
# Out:
#  9 phút, 36 giây 21.986 lượt xem
#  7 phút, 32 giây 105.561 lượt xem
#  9 phút, 58 giây 231.719 lượt xem
#  20 phút 119.902 lượt xem
#  13 phút, 32 giây 62.261 lượt xem
#  21 phút 124.339 lượt xem
#  33 phút 154.799 lượt xem
#  10 phút, 56 giây 114.140 lượt xem
#  24 phút 161.327 lượt xem
#  10 phút, 58 giây 142.356 lượt xem
#  7 phút, 7 giây 246.510 lượt xem
#  22 phút 244.558 lượt xem
#  22 phút 144.004 lượt xem
#  10 phút, 18 giây 95.005 lượt xem
#  5 phút, 29 giây 49.460 lượt xem
#  16 phút 177.218 lượt xem
#  4 giờ, 26 phút 103.617 lượt xem
#  29 phút 107.181 lượt xem
#  31 phút 263.450 lượt xem
#  10 phút, 57 giây 175.227 lượt xem
#  3 phút, 13 giây 40.759 lượt xem
#  34 phút 102.956 lượt xem
#  13 phút, 3 giây 288.427 lượt xem
#  18 phút 116.283 lượt xem
#  12 phút, 44 giây 159.410 lượt xem
#  23 phút 148.545 lượt xem
#  8 phút, 46 giây 177.070 lượt xem
#  12 phút, 48 giây 65.822 lượt xem
#  13 phút, 30 giây 122.632 lượt xem
#  8 phút, 59 giây 72.211 lượt xem

# %%
# Out:
# ['Review',
#  'Phim',
#  'Trở',
#  'Thành',
#  'Thiên',
#  'Tài',
#  'Nhờ',
#  'Ma',
#  'Nhập',
#  '|',
#  'Tóm',
#  'Tắt',
#  'Phim',
#  'Bác',
#  'Sĩ',
#  'Ma',
#  'Bản',
#  'Full',
#  '|',
#  'Review',
#  'Phim',
#  'Hay']

# %%
video_age = a.split(' ')[1:4]

# %%
# Iterate through videos and get titles
for video in videos:
    title = video.find('a', {'aria-label': True})
    title = video.find('a', {'aria-label': True})
    a = title_text.split('Vua Phim Review')[1]
    video_age = a.split(' ')[1:4]
    if title:
        title_text = title['aria-label']
        view = title_text.split('trước')[1]
        #print(title.text)
        #print(view)
        print(video_age)
# Out:
# ['1', 'tháng', 'trước']
# ['22', 'giờ', 'trước']
# ['1', 'ngày', 'trước']
# ['2', 'ngày', 'trước']
# ['4', 'ngày', 'trước']
# ['5', 'ngày', 'trước']
# ['7', 'ngày', 'trước']
# ['8', 'ngày', 'trước']
# ['10', 'ngày', 'trước']
# ['11', 'ngày', 'trước']
# ['12', 'ngày', 'trước']
# ['2', 'tuần', 'trước']
# ['2', 'tuần', 'trước']
# ['2', 'tuần', 'trước']
# ['2', 'tuần', 'trước']
# ['3', 'tuần', 'trước']
# ['3', 'tuần', 'trước']
# ['3', 'tuần', 'trước']
# ['3', 'tuần', 'trước']
# ['3', 'tuần', 'trước']
# ['4', 'tuần', 'trước']
# ['4', 'tuần', 'trước']
# ['1', 'tháng', 'trước']
# ['1', 'tháng', 'trước']
# ['1', 'tháng', 'trước']
# ['1', 'tháng', 'trước']
# ['1', 'tháng', 'trước']
# ['1', 'tháng', 'trước']
# ['1', 'tháng', 'trước']
# ['1', 'tháng', 'trước']
